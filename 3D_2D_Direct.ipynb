# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#2D VS DIRECT
#f_jan

#Number of replicates in each direction
x_direct_2d = [0, 1, 2, 3, 5, 8, 12, 20]
#Energy without lB
y_direct_2d = [-337.511363, -384.669783, -397.995671, -403.425844, -407.476238, -409.571870, -410.794383, -411.793162]

#2D Ewald
plt.axhline(y=-413.186982, color='r', linestyle='-') 
              
plt.plot(x_direct_2d,y_direct_2d)
plt.show()

# %%
#3D VS DIRECT
#test_cubic

#Number of replicates in each direction
x_direct_3d = [0, 1, 2, 3, 4, 5, 8, 20]
#Energy without lB
y_direct_3d = np.array([-18.105640, -15.176257, -12.416276, -12.419802, -12.439313, -12.439800, -12.441339, -12.441617])

#3D Ewald
plt.axhline(y=-13.009839, color='r', linestyle='-') 

#With dipole moment: 0.568164
plt.axhline(y=-12.441675, color='g', linestyle='-') 
plt.plot(x_direct_3d,y_direct_3d)
plt.show()

# %%
#3D VS DIRECT
#f_jan

#Number of replicates in each direction
x_direct_3d = [5, 10]
#Energy without lB
y_direct_3d = np.array([-354.117583, -353.374220])

#3D Ewald
plt.axhline(y=-313.964416, color='r', linestyle='-') 

#With dipole moment: 0.568164
plt.plot(x_direct_3d,y_direct_3d)
plt.show()

# %%
#3D VS 2D
#f_jan

# Z size in terms of slab thickness in the z direction in each of the two directions
x_direct_3d = [0, 1, 2, 3, 4, 5, 10]
#Energy
y_direct_3d = np.array([-26189.646133, -31774.398844, -32872.007693, -33342.925729, -33604.839516, -33772.462445, -34130.650273])

#2D Ewald
plt.axhline(y=-34521.503265, color='r', linestyle='-') 

plt.plot(x_direct_3d,y_direct_3d)
plt.show()
